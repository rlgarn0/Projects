# %%
#import

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy import stats
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
iowa = pd.read_csv('./datasets/train.csv')
iowa.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
iowa.shape
# Out:
# (2051, 81)

# %%
#from https://stackoverflow.com/questions/41476150/removing-space-from-dataframe-columns-in-pandas
#replace space in column names with _
iowa.columns = iowa.columns.str.replace(' ', '_')

# %%
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
# Id                 2051 non-null int64
# PID                2051 non-null int64
# MS_SubClass        2051 non-null int64
# MS_Zoning          2051 non-null object
# Lot_Frontage       1721 non-null float64
# Lot_Area           2051 non-null int64
# Street             2051 non-null object
# Alley              140 non-null object
# Lot_Shape          2051 non-null object
# Land_Contour       2051 non-null object
# Utilities          2051 non-null object
# Lot_Config         2051 non-null object
# Land_Slope         2051 non-null object
# Neighborhood       2051 non-null object
# Condition_1        2051 non-null object
# Condition_2        2051 non-null object
# Bldg_Type          2051 non-null object
# House_Style        2051 non-null object
# Overall_Qual       2051 non-null int64
# Overall_Cond       2051 non-null int64
# Year_Built         2051 non-null int64
# ...

# %% [markdown]
# http://jse.amstat.org/v19n3/decock/DataDocumentation.txt

# %%
#from https://markhneedham.com/blog/2017/07/05/pandas-find-rows-where-columnfield-is-null/
# see null rows
null_columns=iowa.columns[iowa.isnull().any()]
print(iowa[iowa.isnull().any(axis=1)][null_columns])
# Out:
#       Lot_Frontage Alley Mas_Vnr_Type  Mas_Vnr_Area Bsmt_Qual Bsmt_Cond  \
# 0              NaN   NaN      BrkFace         289.0        TA        TA
# 1             43.0   NaN      BrkFace         132.0        Gd        TA
# 2             68.0   NaN         None           0.0        TA        TA
# 3             73.0   NaN         None           0.0        Gd        TA
# 4             82.0   NaN         None           0.0        Fa        Gd
# 5            137.0   NaN         None           0.0        TA        TA
# 6             35.0   NaN      BrkFace          82.0        Gd        TA
# 7              NaN   NaN      BrkFace         180.0        TA        TA
# 8              NaN   NaN         None           0.0        TA        TA
# 9             70.0   NaN      BrkFace         192.0        Gd        TA
# 10            21.0   NaN      BrkFace         232.0        TA        TA
# 11            64.0   NaN         None           0.0        Gd        TA
# ...

# %%
#view rows with missing data
iowa.iloc[1325:1329, 25:40]
# Out:
#      Exterior_2nd Mas_Vnr_Type  Mas_Vnr_Area Exter_Qual Exter_Cond Foundation  \
# 1325      MetalSd         None           0.0         TA         TA     CBlock
# 1326      VinylSd         None           0.0         Gd         TA      PConc
# 1327       CBlock         None           0.0         TA         TA      PConc
# 1328      MetalSd         None           0.0         TA         TA     CBlock
#
#      Bsmt_Qual Bsmt_Cond Bsmt_Exposure BsmtFin_Type_1  BsmtFin_SF_1  \
# 1325        TA        TA            No            ALQ        1084.0
# 1326        Gd        TA            Av            Unf           0.0
# 1327       NaN       NaN           NaN            NaN           NaN
# 1328        TA        TA            Mn            ALQ        1030.0
#
#      BsmtFin_Type_2  BsmtFin_SF_2  Bsmt_Unf_SF  Total_Bsmt_SF
# 1325            Unf           0.0        188.0         1272.0
# 1326            Unf           0.0        672.0          672.0
# ...

# %%
# fill in null vaules for data using VARIABLE DESCRIPTIONS document and zeros of years and sqft of houses that do not
#have an object. 
iowa.Alley.fillna(value = 'No_Alley', inplace=True)
iowa.Pool_QC.fillna(value = 'No_Pool', inplace=True)
iowa.Fence.fillna(value = 'No_Fence', inplace=True)
iowa.Misc_Feature.fillna(value = 'None', inplace=True)
iowa.Fireplace_Qu.fillna(value = 'No_Fireplace', inplace=True)
iowa.Garage_Cond.fillna(value = 'No_Garage', inplace=True)
iowa.Garage_Qual.fillna(value = 'No_Garage', inplace=True)
iowa.Garage_Finish.fillna(value = 'No_Garage', inplace=True)
iowa.Garage_Type.fillna(value = 'No_Garage', inplace=True)
iowa.Bsmt_Qual.fillna(value = 'No_Basement', inplace=True)
iowa.Bsmt_Cond.fillna(value = 'No_Basement', inplace=True)
iowa.Bsmt_Exposure.fillna(value = 'No_Basement', inplace=True)
iowa.BsmtFin_Type_1.fillna(value = 'No_Basement', inplace=True)
iowa.BsmtFin_Type_2.fillna(value = 'No_Basement', inplace=True)
iowa.Mas_Vnr_Type.fillna(value = 'None', inplace=True)
iowa.Lot_Frontage.fillna(value = 0, inplace=True)
iowa.Mas_Vnr_Area.fillna(value = 0, inplace=True)
iowa.Garage_Cars.fillna(value = 0, inplace=True)
iowa.Garage_Area.fillna(value = 0, inplace=True)
iowa.Garage_Yr_Blt.fillna(value = 0, inplace=True)
iowa.Bsmt_Full_Bath.fillna(value = 0, inplace=True)
iowa.Bsmt_Half_Bath.fillna(value = 0, inplace=True)
iowa.BsmtFin_SF_1.fillna(value = 0, inplace=True)
iowa.BsmtFin_SF_2.fillna(value = 0, inplace=True)
iowa.Bsmt_Unf_SF.fillna(value = 0, inplace=True)
iowa.Total_Bsmt_SF.fillna(value = 0, inplace=True)

# %%
#sum of all nulls
iowa.isnull().sum().sum()
# Out:
# 0

# %%
iowa.iloc[:, :30].describe()
# Out:
#                 Id           PID  MS_SubClass  Lot_Frontage       Lot_Area  \
# count  2051.000000  2.051000e+03  2051.000000   2051.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     57.944417   10065.208191
# std     843.980841  1.886918e+08    42.824223     33.137332    6742.488909
# min       1.000000  5.263011e+08    20.000000      0.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     43.500000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     63.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     78.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall_Qual  Overall_Cond   Year_Built  Year_Remod/Add  Mas_Vnr_Area
# count   2051.000000   2051.000000  2051.000000     2051.000000   2051.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     98.626524
# ...

# %%
iowa.iloc[:, 30:50].describe()
# Out:
#        BsmtFin_SF_1  BsmtFin_SF_2  Bsmt_Unf_SF  Total_Bsmt_SF   1st_Flr_SF  \
# count   2051.000000   2051.000000  2051.000000    2051.000000  2051.000000
# mean     442.084837     47.935641   567.451487    1057.471965  1164.488055
# std      461.195041    164.964052   445.022846     449.908003   396.446923
# min        0.000000      0.000000     0.000000       0.000000   334.000000
# 25%        0.000000      0.000000   220.000000     793.000000   879.500000
# 50%      368.000000      0.000000   474.000000     994.000000  1093.000000
# 75%      733.500000      0.000000   811.000000    1318.500000  1405.000000
# max     5644.000000   1474.000000  2336.000000    6110.000000  5095.000000
#
#         2nd_Flr_SF  Low_Qual_Fin_SF  Gr_Liv_Area  Bsmt_Full_Bath  \
# count  2051.000000      2051.000000  2051.000000     2051.000000
# mean    329.329108         5.512921  1499.330083        0.427109
# std     425.671046        51.068870   500.447829        0.522589
# ...

# %%
iowa.iloc[:, 50:68].describe()
# Out:
#          Full_Bath    Half_Bath  Bedroom_AbvGr  Kitchen_AbvGr  TotRms_AbvGrd  \
# count  2051.000000  2051.000000    2051.000000    2051.000000    2051.000000
# mean      1.577279     0.371039       2.843491       1.042906       6.435885
# std       0.549279     0.501043       0.826618       0.209790       1.560225
# min       0.000000     0.000000       0.000000       0.000000       2.000000
# 25%       1.000000     0.000000       2.000000       1.000000       5.000000
# 50%       2.000000     0.000000       3.000000       1.000000       6.000000
# 75%       2.000000     1.000000       3.000000       1.000000       7.000000
# max       4.000000     2.000000       8.000000       3.000000      15.000000
#
#         Fireplaces  Garage_Yr_Blt  Garage_Cars  Garage_Area  Wood_Deck_SF
# count  2051.000000    2051.000000  2051.000000  2051.000000   2051.000000
# mean      0.590931    1868.725987     1.775719   473.440761     93.833740
# ...

# %%
iowa.iloc[:, 68:82].describe()
# Out:
#        Open_Porch_SF  Enclosed_Porch   3Ssn_Porch  Screen_Porch    Pool_Area  \
# count    2051.000000     2051.000000  2051.000000   2051.000000  2051.000000
# mean       47.556802       22.571916     2.591419     16.511458     2.397855
# std        66.747241       59.845110    25.229615     57.374204    37.782570
# min         0.000000        0.000000     0.000000      0.000000     0.000000
# 25%         0.000000        0.000000     0.000000      0.000000     0.000000
# 50%        27.000000        0.000000     0.000000      0.000000     0.000000
# 75%        70.000000        0.000000     0.000000      0.000000     0.000000
# max       547.000000      432.000000   508.000000    490.000000   800.000000
#
#            Misc_Val      Mo_Sold      Yr_Sold      SalePrice
# count   2051.000000  2051.000000  2051.000000    2051.000000
# mean      51.574354     6.219893  2007.775719  181469.701609
# std      573.393985     2.744736     1.312014   79258.659352
# ...

# %%
#Document recommends removing outliers with Gr_Liv_Area more than 4000 sqft
#plot to show outliers
plt.scatter(iowa['SalePrice'], iowa['Gr_Liv_Area'])

# %%
# id rows 
iowa[iowa['Gr_Liv_Area'] > 4000]
# Out:
#         Id        PID  MS_SubClass MS_Zoning  Lot_Frontage  Lot_Area Street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#          Alley Lot_Shape Land_Contour  ... Screen_Porch Pool_Area  Pool_QC  \
# 960   No_Alley       IR3          Bnk  ...            0       480       Gd
# 1885  No_Alley       IR1          Bnk  ...            0         0  No_Pool
#
#          Fence Misc_Feature Misc_Val Mo_Sold Yr_Sold  Sale_Type  SalePrice
# 960   No_Fence         None        0       1    2008        New     160000
# 1885  No_Fence         Elev    17000      10    2007        New     183850
#
# [2 rows x 81 columns]

# %%
#from https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
#drop rows with > 4000 sqft of Ground floor living area.
iowa.drop([960, 1885], inplace = True)

# %%
iowa[iowa['Gr_Liv_Area'] > 4000]
# Out:
# Empty DataFrame
# ...

# %%
#from lesson 3.07 Work Flow
plt.figure(figsize = (10,10))
sns.heatmap(iowa.corr()[['SalePrice']].sort_values('SalePrice'), annot = True, cmap = 'coolwarm')

# %%
neigh = iowa.groupby('Neighborhood').SalePrice.mean().sort_values()

# %%
neigh
# Out:
# Neighborhood
# MeadowV    100231.250000
# IDOTRR     101103.188406
# BrDale     103371.052632
# OldTown    125276.300613
# BrkSide    127022.697368
# Edwards    129905.787234
# SWISU      134758.875000
# Landmrk    137000.000000
# Sawyer     137181.909910
# NPkVill    140476.470588
# Blueste    144566.666667
# NAmes      145905.816129
# Mitchel    167656.707317
# SawyerW    187760.160920
# Greens     188666.666667
# Gilbert    189228.387931
# NWAmes     194619.022989
# Blmngtn    200417.681818
# CollgCr    202497.216667
# Crawfor    205901.211268
# ClearCr    217490.074074
# Somerst    227183.900000
# Timber     241051.354167
# Veenker    253570.588235
# GrnHill    280000.000000
# NoRidge    316294.125000
# NridgHt    322831.352459
# StoneBr    329675.736842
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize = (30,20))
ax = sns.boxplot(iowa['Neighborhood'],iowa['SalePrice'])

# %%
plt.figure(figsize = (30,20))
ax = sns.boxplot(iowa['Overall_Qual'],iowa['SalePrice'])

# %%
fig, ax = plt.subplots(figsize = (10,10))
plt.title("Sale Price vs SqFt")
plt.xlabel('SAT participation')

sns.regplot(x='Gr_Liv_Area', y="SalePrice", data=iowa,)
# sns.regplot(x="sat_2018_participation", y="sat_2018_total", data=final, order=2, ax=ax2)
ax.set_xlabel('Above Ground Living Area SqFt')
ax.set_ylabel('Sale Price $')
# ax2.set_xlabel('')
# ax2.set_ylabel('')

# ax2.legend(handles=[a.lines[0] for a in [ax,ax2]], 
#            labels=["2017", "2018"])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10,10))
plt.title("Log Sale Price vs SqFt")
plt.xlabel('SAT participation')

sns.regplot(x=iowa['Gr_Liv_Area'], y=iowa['SalePrice'].map(np.log))
# sns.regplot(x="sat_2018_participation", y="sat_2018_total", data=final, order=2, ax=ax2)
ax.set_xlabel('Above Ground Living Area SqFt')
ax.set_ylabel('Log Sale Price $')
# ax2.set_xlabel('')
# ax2.set_ylabel('')

# ax2.legend(handles=[a.lines[0] for a in [ax,ax2]], 
#            labels=["2017", "2018"])
plt.show()

# %%
plt.hist(iowa.SalePrice);

# %%
neigh2 = [neigh.index.values]

# %%
neigh2
# Out:
# [array(['MeadowV', 'IDOTRR', 'BrDale', 'OldTown', 'BrkSide', 'Edwards',
#         'SWISU', 'Landmrk', 'Sawyer', 'NPkVill', 'Blueste', 'NAmes',
#         'Mitchel', 'SawyerW', 'Greens', 'Gilbert', 'NWAmes', 'Blmngtn',
#         'CollgCr', 'Crawfor', 'ClearCr', 'Somerst', 'Timber', 'Veenker',
#         'GrnHill', 'NoRidge', 'NridgHt', 'StoneBr'], dtype=object)]

# %%
iowa['SalePrice'].mean()
# Out:
# 181479.01805758907

# %%
#code from Josh
# function to create column with above average saleprice neighborhoods as 1
def richhouse(x):
    rich = ['SawyerW', 'Greens','Gilbert', 'NWAmes', 'Blmngtn',
        'CollgCr', 'Crawfor', 'ClearCr', 'Somerst', 'Timber', 'Veenker',
        'GrnHill', 'NoRidge', 'NridgHt', 'StoneBr']
    if x in rich:
        return 1
    else:
        return 0

# %%
iowa['Abv_Avg_Neigh'] = iowa['Neighborhood']
iowa['Abv_Avg_Neigh'] = iowa['Abv_Avg_Neigh'].map(lambda x: richhouse(x))

# %%
iowa['Abv_Avg_Neigh'].value_counts()
# Out:
# 0    1051
# 1     998
# Name: Abv_Avg_Neigh, dtype: int64

# %%
#dummy columns 
iowa = pd.get_dummies(iowa, columns = ['Foundation', 'Central_Air','Kitchen_Qual', 'Neighborhood'],
                     drop_first = True)

# %%
iowa.head()
# Out:
#     Id        PID  MS_SubClass MS_Zoning  Lot_Frontage  Lot_Area Street  \
# 0  109  533352170           60        RL           0.0     13517   Pave
# 1  544  531379050           60        RL          43.0     11492   Pave
# 2  153  535304180           20        RL          68.0      7922   Pave
# 3  318  916386060           60        RL          73.0      9802   Pave
# 4  255  906425045           50        RL          82.0     14235   Pave
#
#       Alley Lot_Shape Land_Contour  ... Neighborhood_NoRidge  \
# 0  No_Alley       IR1          Lvl  ...                    0
# 1  No_Alley       IR1          Lvl  ...                    0
# 2  No_Alley       Reg          Lvl  ...                    0
# 3  No_Alley       Reg          Lvl  ...                    0
# 4  No_Alley       IR1          Lvl  ...                    0
#
#   Neighborhood_NridgHt Neighborhood_OldTown Neighborhood_SWISU  \
# 0                    0                    0                  0
# ...

# %%
#see corr
plt.figure(figsize = (20,20))
sns.heatmap(iowa.corr()[['SalePrice']].sort_values('SalePrice'), annot = True, cmap = 'coolwarm');

# %%
plt.figure(figsize = (10,10))
ax = sns.boxplot(iowa['Abv_Avg_Neigh'],iowa['SalePrice'])

# %%
plt.scatter(iowa.Garage_Area, iowa.SalePrice)

# %%
#set corr to a data frame
corr =iowa.corr()[['SalePrice']].sort_values('SalePrice')

# %%
#filter corr data frame
corr_features = corr[(corr.SalePrice > .15) & (corr.SalePrice < 1) | (corr.SalePrice < -0.15) ]

# %%
#set X as a list of rows from the corr_features data frame and y as target variable Saleprice
X_feature= [corr_features.index.values]
y= iowa['SalePrice'].map(np.log)

# %%
#check X list of features
X_feature
# Out:
# [array(['Kitchen_Qual_TA', 'Foundation_CBlock', 'PID',
#         'Neighborhood_OldTown', 'Neighborhood_NAmes',
#         'Neighborhood_IDOTRR', 'Neighborhood_Edwards', 'Kitchen_Qual_Fa',
#         'Neighborhood_Somerst', 'Lot_Frontage', 'Bsmt_Unf_SF',
#         '2nd_Flr_SF', 'Neighborhood_StoneBr', 'Garage_Yr_Blt',
#         'Neighborhood_NoRidge', 'Central_Air_Y', 'Half_Bath',
#         'Bsmt_Full_Bath', 'Lot_Area', 'Kitchen_Qual_Gd', 'Wood_Deck_SF',
#         'Open_Porch_SF', 'BsmtFin_SF_1', 'Neighborhood_NridgHt',
#         'Fireplaces', 'TotRms_AbvGrd', 'Mas_Vnr_Area', 'Foundation_PConc',
#         'Full_Bath', 'Year_Remod/Add', 'Year_Built', 'Abv_Avg_Neigh',
#         'Garage_Cars', '1st_Flr_SF', 'Garage_Area', 'Total_Bsmt_SF',
#         'Gr_Liv_Area', 'Overall_Qual'], dtype=object)]

# %%
#copied X feature into X remove Neighborhoods, PID, Mas_Vnr_Area
X= iowa[['Kitchen_Qual_TA', 'Foundation_CBlock',
         'Kitchen_Qual_Fa', 'Lot_Frontage', 'Bsmt_Unf_SF', 'Garage_Yr_Blt', 'Central_Air_Y', 
         'Half_Bath',
        'Bsmt_Full_Bath', 'Lot_Area', 'Kitchen_Qual_Gd', 'Wood_Deck_SF',
        'Open_Porch_SF', 'BsmtFin_SF_1',
        'Fireplaces', 'TotRms_AbvGrd', 'Foundation_PConc',
        'Full_Bath', 'Year_Remod/Add', 'Year_Built', 'Abv_Avg_Neigh',
        'Garage_Cars', 'Garage_Area','Total_Bsmt_SF',
        'Gr_Liv_Area', 'Overall_Qual']]

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
#check shape of training data
X_train.shape
# Out:
# (1536, 26)

# %%
#check shape of test data
X_test.shape
# Out:
# (513, 26)

# %%
#scale data
ss = StandardScaler()
ss.fit(X_train)
X_train_sc = ss.transform(X_train)
X_test_sc = ss.transform(X_test)

# %%
#models cv 5 to get rid of warning
lr = LinearRegression()
la = LassoCV(cv = 5)
rd = RidgeCV()

# %%
cross_val_score(lr, X_train_sc, y_train, cv = 5).mean()
# Out:
# 0.8882445720702712

# %%
cross_val_score(la, X_train_sc, y_train, cv = 5).mean()
# Out:
# 0.8882478519453072

# %%
cross_val_score(rd, X_train_sc, y_train, cv = 5).mean()
# Out:
# 0.8884289323693704

# %%
la.fit(X_train_sc, y_train)
# Out:
# LassoCV(alphas=None, copy_X=True, cv=5, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False)

# %%
la.score(X_train_sc, y_train)
# Out:
# 0.8932754096281151

# %%
#RMSE for LASSO train
la_pred_train=np.exp(la.predict(X_train_sc))
exp_y_train=np.exp(y_train)
(metrics.mean_squared_error(exp_y_train, la_pred_train))**(.5)
# Out:
# 23288.06295463297

# %%
#R2 LASSO Test
la.score(X_test_sc, y_test)
# Out:
# 0.8696964576492557

# %%
#RMSE for LASSO test
la_pred_test=np.exp(la.predict(X_test_sc))
exp_y_test=np.exp(y_test)
(metrics.mean_squared_error(exp_y_test, la_pred_test))**(.5)
# Out:
# 24437.62060899238

# %%
#from Temple
# RMSE for the avg sale price. Null model score.
from sklearn.dummy import DummyRegressor
dummy_mean = DummyRegressor(strategy='mean')
dummy_mean.fit(X_train_sc, y_train)
dum_pred_train=np.exp(dummy_mean.predict(X_train_sc))
exp_y_train=np.exp(y_train)
(metrics.mean_squared_error(exp_y_train, dum_pred_train))**(.5)
# Out:
# 80551.607016884

# %%
#see coeff of LASSO model by features
coef = pd.DataFrame([la.coef_])

coef.columns = X.columns

coef.T
# Out:
#                           0
# Kitchen_Qual_TA   -0.044618
# Foundation_CBlock  0.003528
# Kitchen_Qual_Fa   -0.025427
# Lot_Frontage       0.006628
# Bsmt_Unf_SF       -0.015863
# Garage_Yr_Blt      0.018610
# Central_Air_Y      0.028372
# Half_Bath         -0.000000
# Bsmt_Full_Bath     0.010355
# Lot_Area           0.030791
# Kitchen_Qual_Gd   -0.031035
# Wood_Deck_SF       0.006282
# Open_Porch_SF      0.001753
# BsmtFin_SF_1       0.025615
# Fireplaces         0.027270
# TotRms_AbvGrd      0.008425
# Foundation_PConc   0.014107
# Full_Bath         -0.000891
# Year_Remod/Add     0.040628
# Year_Built         0.035295
# Abv_Avg_Neigh      0.014264
# Garage_Cars        0.001551
# Garage_Area        0.014153
# Total_Bsmt_SF      0.061257
# Gr_Liv_Area        0.108057
# Overall_Qual       0.119384

# %%
#plot for Presentation
X2= iowa[['Kitchen_Qual_TA', 'Foundation_CBlock',
         'Kitchen_Qual_Fa', 'Lot_Frontage', 'Bsmt_Unf_SF', 'Garage_Yr_Blt', 'Central_Air_Y', 
         'Half_Bath',
        'Bsmt_Full_Bath', 'Lot_Area', 'Kitchen_Qual_Gd', 'Wood_Deck_SF',
        'Open_Porch_SF', 'BsmtFin_SF_1',
        'Fireplaces', 'TotRms_AbvGrd', 'Foundation_PConc',
        'Full_Bath', 'Year_Remod/Add', 'Year_Built', 'Abv_Avg_Neigh',
        'Garage_Cars', 'Garage_Area','Total_Bsmt_SF',
        'Gr_Liv_Area', 'Overall_Qual', 'SalePrice']]
plt.figure(figsize = (20,20))
sns.heatmap(X2.corr()[['SalePrice']].sort_values('SalePrice'), annot = True, cmap = 'coolwarm');

# %%
i_test = pd.read_csv('./datasets/test.csv')
i_test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
i_test.columns = i_test.columns.str.replace(' ', '_')
i_test.Alley.fillna(value = 'No_Alley', inplace=True)
i_test.Pool_QC.fillna(value = 'No_Pool', inplace=True)
i_test.Fence.fillna(value = 'No_Fence', inplace=True)
i_test.Misc_Feature.fillna(value = 'None', inplace=True)
i_test.Fireplace_Qu.fillna(value = 'No_Fireplace', inplace=True)
i_test.Garage_Cond.fillna(value = 'No_Garage', inplace=True)
i_test.Garage_Qual.fillna(value = 'No_Garage', inplace=True)
i_test.Garage_Finish.fillna(value = 'No_Garage', inplace=True)
i_test.Garage_Type.fillna(value = 'No_Garage', inplace=True)
i_test.Bsmt_Qual.fillna(value = 'No_Basement', inplace=True)
i_test.Bsmt_Cond.fillna(value = 'No_Basement', inplace=True)
i_test.Bsmt_Exposure.fillna(value = 'No_Basement', inplace=True)
i_test.BsmtFin_Type_1.fillna(value = 'No_Basement', inplace=True)
i_test.BsmtFin_Type_2.fillna(value = 'No_Basement', inplace=True)
i_test.Mas_Vnr_Type.fillna(value = 'None', inplace=True)
i_test.Lot_Frontage.fillna(value = 0, inplace=True)
i_test.Mas_Vnr_Area.fillna(value = 0, inplace=True)
i_test.Garage_Cars.fillna(value = 0, inplace=True)
i_test.Garage_Area.fillna(value = 0, inplace=True)
i_test.Garage_Yr_Blt.fillna(value = 0, inplace=True)
i_test.Bsmt_Full_Bath.fillna(value = 0, inplace=True)
i_test.Bsmt_Half_Bath.fillna(value = 0, inplace=True)
i_test.BsmtFin_SF_1.fillna(value = 0, inplace=True)
i_test.BsmtFin_SF_2.fillna(value = 0, inplace=True)
i_test.Bsmt_Unf_SF.fillna(value = 0, inplace=True)
i_test.Total_Bsmt_SF.fillna(value = 0, inplace=True)

# %%
i_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
# Id                 879 non-null int64
# PID                879 non-null int64
# MS_SubClass        879 non-null int64
# MS_Zoning          879 non-null object
# Lot_Frontage       879 non-null float64
# Lot_Area           879 non-null int64
# Street             879 non-null object
# Alley              879 non-null object
# Lot_Shape          879 non-null object
# Land_Contour       879 non-null object
# Utilities          879 non-null object
# Lot_Config         879 non-null object
# Land_Slope         879 non-null object
# Neighborhood       879 non-null object
# Condition_1        879 non-null object
# Condition_2        879 non-null object
# Bldg_Type          879 non-null object
# House_Style        879 non-null object
# Overall_Qual       879 non-null int64
# Overall_Cond       879 non-null int64
# Year_Built         879 non-null int64
# ...

# %%
i_test['Abv_Avg_Neigh'] = i_test['Neighborhood']
i_test['Abv_Avg_Neigh'] = i_test['Abv_Avg_Neigh'].map(lambda x: richhouse(x))

# %%
i_test = pd.get_dummies(i_test, columns = ['Foundation','Central_Air','Kitchen_Qual', 'Neighborhood'],
                     drop_first = True)

# %%
i_test.shape
# Out:
# (879, 112)

# %%
X_i_test= i_test[['Kitchen_Qual_TA', 'Foundation_CBlock',
         'Kitchen_Qual_Fa', 'Lot_Frontage', 'Bsmt_Unf_SF', 'Garage_Yr_Blt', 'Central_Air_Y', 
         'Half_Bath',
        'Bsmt_Full_Bath', 'Lot_Area', 'Kitchen_Qual_Gd', 'Wood_Deck_SF',
        'Open_Porch_SF', 'BsmtFin_SF_1',
        'Fireplaces', 'TotRms_AbvGrd', 'Foundation_PConc',
        'Full_Bath', 'Year_Remod/Add', 'Year_Built', 'Abv_Avg_Neigh',
        'Garage_Cars', 'Garage_Area', 'Total_Bsmt_SF',
        'Gr_Liv_Area', 'Overall_Qual']]

# %%
X_i_test_sc = ss.transform(X_i_test)

# %%
pred = np.exp(la.predict(X_i_test_sc))

# %%
len(pred)
# Out:
# 879

# %%
submission_pd = pd.DataFrame(i_test.Id)

# %%
submission_pd.shape
# Out:
# (879, 1)

# %%
submission_pd['SalePrice'] = pred

# %%
submission_pd.head()
# Out:
#      Id      SalePrice
# 0  2658  117402.956066
# 1  2718  169710.661983
# 2  2414  213000.426646
# 3  1989  117015.644745
# 4   625  166795.562354

# %%
submission_pd.to_csv('submission4.csv')

# %%
submission_pd.to_csv('submission.csv', index=False)
